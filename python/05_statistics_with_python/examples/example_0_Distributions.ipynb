# %%
import pandas as pd 
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Cheatsheet https://chatgpt.com/share/678198c0-cfa0-8010-be4c-df55c66943d6

# %%
# Normal Distribution

samples = np.random.normal(0, 1, 1000000)
sns.histplot(samples, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
uniform = np.random.uniform(0, 1, 1000000)
sns.histplot(uniform)
# Out:
# <Axes: ylabel='Count'>

# %%
mean = 1
std = .01
samples1 = np.random.normal(mean, std, 100)
samples2 = np.random.normal(mean, std, 100)
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.scatter(samples1, samples2)

# %%
from scipy.stats import t, norm

df = 5  # Degrees of Freedom
x = np.linspace(-4, 4, 100)
pdf_t = t.pdf(x, df)
pdf_norm = norm.pdf(x)
plt.plot(x, pdf_t)
plt.plot(x, pdf_norm)
